# %%
import numpy as np
import random as ri

# %%
import random

id1 = input("id please: ")
password = input("password please: ")

if id1 != "maly" and password != "12345":
    print("generate otp")
    system_otp = random.randint(1000, 9999)
    print("system otp is", system_otp)

    user_otp = int(input("enter your otp: "))
    if system_otp == user_otp:
        print("reset user password")
    else:
        print("wrong otp")
else:
    print("log in successful")
# Out:
# id please:  ghj
# password please:  76
# generate otp
# system otp is 2056
# enter your otp:  767
# wrong otp
